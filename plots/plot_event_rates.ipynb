# %%
# %config InlineBackend.figure_format = 'retina'
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np

#plt.rcParams["font.family"] = "Times"
#font = {'family' : 'Times',
#        'weight' : 'bold',
#        'size'   : 22}

font = {'family' : 'Times',
        'size'   : 18}

plt.rc('font', **font)
#plt.style.use('seaborn')

detconfigname = "ar40kt"
fluxname = "gvkm"
channelfile = "argon"

chanfilename = "../channels/channels_"+channelfile+".dat"
chans = np.genfromtxt(chanfilename,dtype={'names': ('cname', 'num', 'cpstate','flavor','ntargets'),'formats': ('U16', 'i', 'U12','U12','i')})

# Go through the channels in the channel file
ich=0



while ich<chans.size:
    #print(chans['cname'][ich],chans['cpstate'][ich])
    channame = chans['cname'][ich]
    #print(channame)
    smearedfilename = "../out/"+fluxname+"_"+str(channame)+"_"+detconfigname+"_events_smeared.dat"
    print(smearedfilename)
    smeared = np.loadtxt(smearedfilename, comments=['#', '--', 'Total'], skiprows=0)
 
    energyingev = smeared[:,0]
    energyinmev = energyingev*1000.

    smeared_events = smeared[:,1]
#    plt.plot(energyinmev,xscn_nue,label=r'$\bar{\nu}_e$')
    if not "nc" in channame:
        plt.plot(energyinmev,smeared_events,label=chans['cname'][ich])
    
    ich=ich+1


plt.xlabel("Observed Energy (MeV)")
plt.ylabel("Events per bin")
plt.legend(loc='upper right',prop={'size': 12})
# Out:
# ../out/gvkm_nue_e_ar40kt_events_smeared.dat
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-6a41c055023f> in <module>
#      33     smearedfilename = "../out/"+fluxname+"_"+str(channame)+"_"+detconfigname+"_events_smeared.dat"
#      34     print(smearedfilename)
# ---> 35     smeared = np.loadtxt(smearedfilename, comments=['#', '--', 'Total'], skiprows=0)
#      36
#      37     energyingev = smeared[:,0]
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     959             fname = os_fspath(fname)
#     960         if _is_string_like(fname):
# --> 961             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     962             fencoding = getattr(fh, 'encoding', 'latin1')
#     963             fh = iter(fh)
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     193
#     194     ds = DataSource(destpath)
# --> 195     return ds.open(path, mode, encoding=encoding, newline=newline)
#     196
#     197
#
# ~/.local/lib/python3.6/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     533                                       encoding=encoding, newline=newline)
#     534         else:
# --> 535             raise IOError("%s not found." % path)
#     536
#     537
#
# OSError: ../out/gvkm_nue_e_ar40kt_events_smeared.dat not found.

# %%
ich=0

while ich<chans.size:
    #print(chans['cname'][ich],chans['cpstate'][ich])
    channame = chans['cname'][ich]
    #print(channame)
    interactedfilename = "../out/"+fluxname+"_"+str(channame)+"_"+detconfigname+"_events.dat"
    print(interactedfilename)
    interacted = np.loadtxt(interactedfilename, comments=['#', '--', 'Total'], skiprows=0)
    energyingev = smeared[:,0]
    energyinmev = energyingev*1000.

    interacted_events = interacted[:,1]
#    plt.plot(energyinmev,xscn_nue,label=r'$\bar{\nu}_e$')
    if not "nc" in channame:
        plt.plot(energyinmev,interacted_events,label=chans['cname'][ich])
    
    ich=ich+1
    
plt.xlabel("Interacted Neutrino Energy (MeV)")
plt.ylabel("Events per bin")
plt.legend(loc='upper right',prop={'size': 12})
# Out:
# ../out/livermore_nue_e_dune_events.dat
# ../out/livermore_marley_dune_events.dat
# ../out/livermore_gtbd_dune_events.dat
# ../out/livermore_pqrpa_dune_events.dat
# ../out/livermore_qrpa_dune_events.dat
# ../out/livermore_rpa_dune_events.dat
# ../out/livermore_rsrpa_dune_events.dat
# ../out/livermore_sm_rpa_dune_events.dat
